# %%
import pandas as pd     #Pandas - To read data 
import numpy as np    #Numpy - Mathematical operations
import matplotlib.pyplot as plt    #PLT - To create visualizations

# %%
data = pd.read_csv("/home/skyline/Downloads/datasets/season.csv")

# %%
data.head()
# Out:
#    Sales  Ads  Quarter  d1  d2  d3  d4
# 0     86  5.5        1   1   0   0   0
# 1     90  6.0        2   0   1   0   0
# 2    100  8.0        3   0   0   1   0
# 3     93  7.0        4   0   0   0   1
# 4     97  7.5        1   1   0   0   0

# %%
data.describe()
# Out:
#             Sales        Ads    Quarter         d1         d2         d3  \
# count   60.000000  60.000000  60.000000  60.000000  60.000000  60.000000
# mean   332.366667  12.641667   2.500000   0.250000   0.250000   0.250000
# std    176.067106   3.982346   1.127469   0.436667   0.436667   0.436667
# min     86.000000   5.500000   1.000000   0.000000   0.000000   0.000000
# 25%    189.750000   9.675000   1.750000   0.000000   0.000000   0.000000
# 50%    309.500000  12.200000   2.500000   0.000000   0.000000   0.000000
# 75%    456.000000  15.275000   3.250000   0.250000   0.250000   0.250000
# max    702.000000  24.000000   4.000000   1.000000   1.000000   1.000000
#
#               d4
# count  60.000000
# mean    0.250000
# std     0.436667
# min     0.000000
# 25%     0.000000
# 50%     0.000000
# 75%     0.250000
# max     1.000000

# %% [markdown]
# ## Dropped Alpha

# %%
import statsmodels.api as sm
x = data[['d1', 'd2', 'd3', 'd4']]
y = data['Sales']

model = sm.OLS(y,x).fit()
predictions = model.predict(x)
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                 -0.044
# Method:                 Least Squares   F-statistic:                    0.1795
# Date:                Thu, 28 Oct 2021   Prob (F-statistic):              0.910
# Time:                        11:47:22   Log-Likelihood:                -394.60
# No. Observations:                  60   AIC:                             797.2
# Df Residuals:                      56   BIC:                             805.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# d1           313.0000     46.439      6.740      0.000     219.971     406.029
# ...

# %%
import statsmodels.api as sm
x = data[['d2', 'd3', 'd4']]
y = data['Sales']

x = sm.add_constant(x)
model = sm.OLS(y,x).fit()
predictions = model.predict(x)
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                 -0.044
# Method:                 Least Squares   F-statistic:                    0.1795
# Date:                Thu, 28 Oct 2021   Prob (F-statistic):              0.910
# Time:                        11:48:13   Log-Likelihood:                -394.60
# No. Observations:                  60   AIC:                             797.2
# Df Residuals:                      56   BIC:                             805.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        313.0000     46.439      6.740      0.000     219.971     406.029
# ...

# %%
data2 = pd.read_csv("/home/skyline/Downloads/datasets/Interaction.csv")
data
# Out:
#     Year  Advertisement  Sales  Dummy_year  int_variable
# 0   1971             24  12000           0             0
# 1   1972             22  12000           0             0
# 2   1873             23  14000           0             0
# 3   1974             24  15000           0             0
# 4   1975             25  14560           0             0
# 5   1976             28  15450           0             0
# 6   1977             27  15432           0             0
# 7   1978             29  15890           0             0
# 8   1979             29  15640           0             0
# 9   1980             31  16543           0             0
# 10  1981             32  16790           0             0
# 11  1982             33  16890           0             0
# 12  1983             35  17200           0             0
# 13  1984             35  17340           0             0
# 14  1985             36  18190           0             0
# ...

# %%
import statsmodels.api as sm
x = data[['Dummy_year', 'Advertisement', 'int_variable']]
y = data['Sales']

x = sm.add_constant(x)
model = sm.OLS(y,x).fit()
predictions = model.predict(x)
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.979
# Model:                            OLS   Adj. R-squared:                  0.977
# Method:                 Least Squares   F-statistic:                     550.5
# Date:                Thu, 28 Oct 2021   Prob (F-statistic):           4.06e-30
# Time:                        12:43:41   Log-Likelihood:                -340.42
# No. Observations:                  40   AIC:                             688.8
# Df Residuals:                      36   BIC:                             695.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...
